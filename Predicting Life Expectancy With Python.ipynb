# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("https://raw.githubusercontent.com/SmartPracticeschool/llSPS-INT-2122-Predicting-Life-Expectancy-using-Machine-Learning/master/dataset/Life%20Expectancy%20Data.csv")
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df=df.groupby("Country").mean()

# %%
df.head()
# Out:
#                        Year  Life expectancy   Adult Mortality  infant deaths  \
# Country
# Afghanistan          2007.5          58.19375         269.0625        78.2500
# Albania              2007.5          75.15625          45.0625         0.6875
# Algeria              2007.5          73.61875         108.1875        20.3125
# Angola               2007.5          49.01875         328.5625        83.7500
# Antigua and Barbuda  2007.5          75.05625         127.5000         0.0000
#
#                       Alcohol  percentage expenditure  Hepatitis B   Measles   \
# Country
# Afghanistan          0.014375               34.960110    64.562500  2362.2500
# Albania              4.848750              193.259091    98.000000    53.3750
# Algeria              0.406667              236.185241    78.000000  1943.8750
# Angola               5.740667              102.100268    70.222222  3561.3125
# Antigua and Barbuda  7.949333             1001.585226    98.266667     0.0000
#
# ...

# %%
df=df.drop('Year',axis=1)

# %%
df.isna().count()
# Out:
# Life expectancy                    193
# Adult Mortality                    193
# infant deaths                      193
# Alcohol                            193
# percentage expenditure             193
# Hepatitis B                        193
# Measles                            193
#  BMI                               193
# under-five deaths                  193
# Polio                              193
# Total expenditure                  193
# Diphtheria                         193
#  HIV/AIDS                          193
# GDP                                193
# Population                         193
#  thinness  1-19 years              193
#  thinness 5-9 years                193
# Income composition of resources    193
# Schooling                          193
# dtype: int64

# %%
df=df.dropna()

# %%
df.head()
# Out:
#              Life expectancy   Adult Mortality  infant deaths   Alcohol  \
# Country
# Afghanistan          58.19375         269.0625        78.2500  0.014375
# Albania              75.15625          45.0625         0.6875  4.848750
# Algeria              73.61875         108.1875        20.3125  0.406667
# Angola               49.01875         328.5625        83.7500  5.740667
# Argentina            75.15625         106.0000        10.1250  7.966667
#
#              percentage expenditure  Hepatitis B   Measles       BMI   \
# Country
# Afghanistan               34.960110    64.562500  2362.2500  15.51875
# Albania                  193.259091    98.000000    53.3750  49.06875
# Algeria                  236.185241    78.000000  1943.8750  48.74375
# Angola                   102.100268    70.222222  3561.3125  18.01875
# Argentina                773.038981    81.285714     2.0000  54.98125
#
#              under-five deaths    Polio  Total expenditure  Diphtheria   \
# Country
# ...

# %%
le=df.iloc[:,0]

# %%
df1=df.drop(['Life expectancy '],axis=1)

# %%
df1
# Out:
#                           Adult Mortality  infant deaths    Alcohol  \
# Country
# Afghanistan                      269.0625        78.2500   0.014375
# Albania                           45.0625         0.6875   4.848750
# Algeria                          108.1875        20.3125   0.406667
# Angola                           328.5625        83.7500   5.740667
# Argentina                        106.0000        10.1250   7.966667
# Armenia                          117.3750         1.0000   3.702667
# Australia                         63.1875         1.0000  10.155333
# Austria                           65.7500         0.0000  12.236000
# Azerbaijan                       115.1875         6.0625   0.992000
# Bangladesh                       141.3750       153.6250   0.010000
# Belarus                          218.7500         0.5625  13.497333
# Belgium                           70.1875         0.2500  11.042667
# Belize                           155.5000         0.0000   6.252667
# ...

# %%
plt.scatter(df1.iloc[:,0],le)
plt.xlabel(df1.columns.values[0])
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(df1.iloc[:,1],le)
plt.xlabel(df1.columns.values[1])
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(df1.iloc[:,2],le)
plt.xlabel(df1.columns.values[2])
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(df1.iloc[:,3],le)
plt.xlabel(df1.columns.values[3])
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(df1.iloc[:,4],le)
plt.xlabel(df1.columns.values[4])
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(df1.iloc[:,5],le)
plt.xlabel(df1.columns.values[5])
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(df1.iloc[:,6],le)
plt.xlabel(df1.columns.values[6])
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(df1.iloc[:,7],le)
plt.xlabel(df1.columns.values[7])
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(df1.iloc[:,8],le)
plt.xlabel(df1.columns.values[8])
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(df1.iloc[:,9],le)
plt.xlabel(df1.columns.values[9])
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(df1.iloc[:,10],le)
plt.xlabel(df1.columns.values[10])
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(df1.iloc[:,11],le)
plt.xlabel(df1.columns.values[11])
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(df1.iloc[:,12],le)
plt.xlabel(df1.columns.values[12])
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(df1.iloc[:,13],le)
plt.xlabel(df1.columns.values[13])
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(df1.iloc[:,14],le)
plt.xlabel(df1.columns.values[14])
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(df1.iloc[:,15],le)
plt.xlabel(df1.columns.values[15])
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(df1.iloc[:,16],le)
plt.xlabel(df1.columns.values[16])
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(df1.iloc[:,17],le)
plt.xlabel(df1.columns.values[17])
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
df1=df1.drop('infant deaths',axis=1)

# %%
df1.columns.values
# Out:
# array(['Adult Mortality', 'Alcohol', 'percentage expenditure',
#        'Hepatitis B', 'Measles ', ' BMI ', 'under-five deaths ', 'Polio',
#        'Total expenditure', 'Diphtheria ', ' HIV/AIDS', 'GDP',
#        'Population', ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'], dtype=object)

# %%
df1=df1.drop('Measles ',axis=1)

# %%
df1=df1.drop('under-five deaths ',axis=1)

# %%
df1=df1.drop('Population',axis=1)

# %%
df1=df1.drop(' thinness  1-19 years',axis=1)

# %%
df1=df1.drop(' thinness 5-9 years',axis=1)

# %%
df1=df1.drop(' HIV/AIDS',axis=1)

# %%
df1.columns.values
# Out:
# array(['Adult Mortality', 'Alcohol', 'percentage expenditure',
#        'Hepatitis B', ' BMI ', 'Polio', 'Total expenditure',
#        'Diphtheria ', 'GDP', 'Income composition of resources',
#        'Schooling'], dtype=object)

# %%
df=pd.concat([df1,le],axis=1)

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df1,le,test_size=.20,random_state=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
model=lr.fit(x_train,y_train)

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.910272680312535

# %%
x_train.columns.values
# Out:
# array(['Adult Mortality', 'Alcohol', 'percentage expenditure',
#        'Hepatitis B', ' BMI ', 'Polio', 'Total expenditure',
#        'Diphtheria ', 'GDP', 'Income composition of resources',
#        'Schooling'], dtype=object)

# %%
values=[[100,2,10,80,20,80,100,65,10000,.41,20]]
#values=values.values.reshape(-1,1)
lr.predict(values)
# Out:
# array([68.40645219])

# %%
from watson_machine_learning_client import WatsonMachineLearningAPIClient

# %%
wml_credentials={
  "apikey": "Lw2DiF0jlAOUgplP2bc6ybKAW9PHsj_-NQwNYT7ue_dC",
  "iam_apikey_description": "Auto-generated for key ff2f38a5-31d5-4b89-b798-8e75d60b14a1",
  "iam_apikey_name": "wdp-writer",
  "iam_role_crn": "crn:v1:bluemix:public:iam::::serviceRole:Writer",
  "iam_serviceid_crn": "crn:v1:bluemix:public:iam-identity::a/846d6485fcd548aca5a7443d8cce3bf8::serviceid:ServiceId-a9b37aee-08db-4280-aa96-59421ab96f61",
  "instance_id": "ad2b1e18-25ba-4cfe-bb2e-3426341b4ba9",
  "url": "https://us-south.ml.cloud.ibm.com"
}

# %%
client=WatsonMachineLearningAPIClient(wml_credentials)

# %%
model_props={
    client.repository.ModelMetaNames.AUTHOR_NAME : "Milan Vishnoi",
    client.repository.ModelMetaNames.AUTHOR_EMAIL : "si052020000266@smartinternz.com",
    client.repository.ModelMetaNames.NAME:"Life Expectancy Predcitor"
}

# %%
model_artifacts=client.repository.store_model(lr,meta_props=model_props)

# %%
guid=client.repository.get_model_uid(model_artifacts)

# %%
deploy=client.deployments.create(guid,name="Predicting Life Expectancy With Python")
# Out:
# #######################################################################################
#
# Synchronous deployment creation for uid: '36396a7b-6668-4684-a1c0-3a6342f5f5d8' started
#
# #######################################################################################
#
#
# INITIALIZING
# DEPLOY_SUCCESS
#
#
# ------------------------------------------------------------------------------------------------
# Successfully finished deployment creation, deployment_uid='334589b6-9b0b-4b13-baad-d05ab2e9612d'
# ------------------------------------------------------------------------------------------------

# %%
deploy
# Out:
# {'metadata': {'guid': '334589b6-9b0b-4b13-baad-d05ab2e9612d',
#   'url': 'https://us-south.ml.cloud.ibm.com/v3/wml_instances/ad2b1e18-25ba-4cfe-bb2e-3426341b4ba9/deployments/334589b6-9b0b-4b13-baad-d05ab2e9612d',
#   'created_at': '2020-06-09T17:43:10.016Z',
#   'modified_at': '2020-06-09T17:43:10.358Z'},
#  'entity': {'runtime_environment': 'python-3.6',
#   'name': 'Predicting Life Expectancy With Python',
#   'scoring_url': 'https://us-south.ml.cloud.ibm.com/v3/wml_instances/ad2b1e18-25ba-4cfe-bb2e-3426341b4ba9/deployments/334589b6-9b0b-4b13-baad-d05ab2e9612d/online',
#   'deployable_asset': {'name': 'Life Expectancy Predcitor',
#    'url': 'https://us-south.ml.cloud.ibm.com/v3/wml_instances/ad2b1e18-25ba-4cfe-bb2e-3426341b4ba9/published_models/36396a7b-6668-4684-a1c0-3a6342f5f5d8',
#    'guid': '36396a7b-6668-4684-a1c0-3a6342f5f5d8',
#    'created_at': '2020-06-09T17:43:09.987Z',
#    'type': 'model'},
#   'description': 'Description of deployment',
# ...
